# %%
import os

# move to project root
while True:
    # get list of directories
    dirs = os.listdir()
    if "README.md" in dirs:
        break
    else:
        os.chdir("..")
print(os.getcwd())
# Out:
# /home/ra/Codes/timescales_filtering

# %%
from feature_extraction.utils import load_story_info
# Out:
# Using gpu

# %%
import os

# %%
zh_textgrid_dir= "data/zh/grids"
zh_trfiles_dir = "data/zh/trfiles"

en_textgrid_dir= "data/en/grids"
en_trfiles_dir = "data/en/trfiles"

# %%
stories =[
    "aliceinwonderland",
    "harrypotter",
    "littleprince",
    
]

# %%
grids = load_story_info(
    story_name=stories[0],
    trfile_dir=zh_trfiles_dir,
    grid_dir=zh_textgrid_dir)
# Out:
# load_grids_for_stories ['aliceinwonderland'] data/zh/grids

# %%
# Out:
# array([  4.00597925,   6.01156925,   8.01495125,  10.01917725,
#         12.02452525,  14.02813425,  16.03288125,  18.03598425,
#         20.04169325,  22.04736125,  24.05154525,  26.05639025,
#         28.06114825,  30.06399625,  32.06937425,  34.07216025,
#         36.07696425,  38.08280325,  40.08548925,  42.09323825,
#         44.09447725,  46.10189925,  48.10567625,  50.10940825,
#         52.11446125,  54.11957825,  56.12385725,  58.12830225,
#         60.13281625,  62.13655425,  64.14158525,  66.14364125,
#         68.15032425,  70.15529425,  72.15940325,  74.16570725,
#         76.16799225,  78.17351925,  80.17657725,  82.18139125,
#         84.18574625,  86.19089125,  88.19602325,  90.20070025,
#         92.20429625,  94.20998425,  96.21318425,  98.21793425,
#        100.22246425, 102.22555425, 104.23121625, 106.23727925,
#        108.23942525, 110.24615725, 112.24879125, 114.25336525,
#        116.25742525, 118.26288125, 120.26831325, 122.27252025,
# ...
